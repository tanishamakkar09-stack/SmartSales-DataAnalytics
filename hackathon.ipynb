# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("gen ai csv.csv")
df.head()
# Out:
#   Order ID Customer ID Product Category  Purchase Amount        Date  \
# 0   ORD001        C001      Electronics             3499  2024-01-05
# 1   ORD002        C002          Fashion             1299  2024-01-06
# 2   ORD003        C003       Home Decor             2599  2024-01-06
# 3   ORD004        C004           Beauty              799  2024-01-07
# 4   ORD005        C005      Electronics             5499  2024-01-07
#
#     Location
# 0     Mumbai
# 1      Delhi
# 2  Bangalore
# 3       Pune
# 4  Hyderabad

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          100 non-null    object
#  1   Customer ID       100 non-null    object
#  2   Product Category  100 non-null    object
#  3   Purchase Amount   100 non-null    int64
#  4   Date              100 non-null    object
#  5   Location          100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#        Purchase Amount
# count       100.000000
# mean       2455.900000
# std        2256.575888
# min         299.000000
# 25%         799.000000
# 50%        1799.000000
# 75%        2599.000000
# max        8999.000000

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
category_sales = df.groupby("Product Category")["Purchase Amount"].sum()

plt.figure(figsize=(8,5))
category_sales.plot(kind='bar')
plt.xlabel("Product Category")
plt.ylabel("Total Sales")
plt.title("Sales by Product Category")
plt.show()

# %%
df['Month'] = df['Date'].dt.to_period('M')

monthly_sales = df.groupby("Month")["Purchase Amount"].sum()

plt.figure(figsize=(9,5))
monthly_sales.plot(kind="line", marker="o")
plt.xlabel("Month")
plt.ylabel("Sales Amount")
plt.title("Monthly Sales Trend")
plt.show()
